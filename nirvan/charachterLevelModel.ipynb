# %%
from __future__ import print_function

from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np
# Out:
# Using TensorFlow backend.
# C:\Python\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Python\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Python\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Python\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Python\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Python\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
batch_size = 64  # Batch size for training.
epochs = 5  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 100000  # Number of samples to train on.

# Path to the data txt file on disk.
data_path = 'fra.txt'
# data_path = 'joey.npy'
if '.txt' in data_path:
    with open(data_path, 'r', encoding='utf-8') as f:
        lines = f.read().split('\n')
    for idx,line in enumerate(lines):
        lines[idx]="\t".join(line.split('\t')[0:-1])
if '.npy' in data_path:
    lines = str(np.load(data_path)).split('\n')

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
for line in lines[: min(num_samples, len(lines) - 1)]:
#     input_text, target_text, _ = line.split('\t')
    input_text, target_text = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)

input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.
# Out:
# Number of samples: 100000
# Number of unique input tokens: 79
# Number of unique output tokens: 107
# Max sequence length for inputs: 31
# Max sequence length for outputs: 78

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Save model
model.save('s2s.h5')
# Out:
# WARNING:tensorflow:From C:\Python\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Python\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Python\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 80000 samples, validate on 20000 samples
# Epoch 1/5

# %%
# Next: inference mode (sampling).
# Here's the drill:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token
# 3) Repeat with the current target token and current states

# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: ooh... i love barbados!
# Decoded sentence: o
# -
# Input sentence: hey, you know, before you said that nothing could happen between us? what changed?
# Decoded sentence: o
# -
# Input sentence: rach, you there?
# Decoded sentence: o
# -
# Input sentence: oh, ju-ju-just stay calm. just be calm. for all he knows we're just hanging out together. right? just be nonchalant.  that's not nonchalant!
# Decoded sentence: o
# -
# Input sentence: yeah, sure...
# Decoded sentence: o
# -
# Input sentence: you would think! joey!
# Decoded sentence: o
# -
# Input sentence: how are you doing this?
# Decoded sentence: o
# -
# Input sentence: oh no... have you thought about it how complicated this could get? what about ross?
# Decoded sentence: o
# -
# Input sentence: yeah, but he wants to talk to you before anything really happens with her. and as his friend, i mean, don't you think he deserves the same from you?
# Decoded sentence: o
# -
# Input sentence: get out! are they right?
# Decoded sentence: o
# -
# Input sentence: yeah... yeah, we can wait, we don't have to do anything tonight.
# Decoded sentence: o
# -
# Input sentence: although...
# Decoded sentence: o
# -
# Input sentence: i mean, you know... ross and i haven't dated in like... six years...
# Decoded sentence: o
# -
# Input sentence: plus, you know, he is with charlie now.
# Decoded sentence: o
# -
# Input sentence: no...
# Decoded sentence: o
# -
# Input sentence: yeah...
# Decoded sentence: o
# -
# Input sentence: forgotten.
# Decoded sentence: o
# -
# Input sentence: nothing... nothing... it's really... it's nothing... come here, come here... sorry, i just uhm... i can't seem to get ross out of my head...
# Decoded sentence: o
# -
# Input sentence: what d'ya know... it's a treat for the eyes and the ears.
# Decoded sentence: o
# -
# Input sentence: yeah, it's almost if air barbados doesn't care about your social life.
# Decoded sentence: o
# -
# Input sentence: oh, i uh, i mean, i... dude, i spent the whole conference with charlie.
# Decoded sentence: o
# -
# Input sentence: ross is coming over. i think now would be a really good time to talk to him.
# Decoded sentence: o
# -
# Input sentence: okay, well keep in mind that by the time you're done, they'll probably be serving dinner.
# Decoded sentence: o
# -
# Input sentence: still nervous?
# Decoded sentence: o
# -
# Input sentence: hey!
# Decoded sentence: o
# -
# Input sentence: so, i uhm... kinda need to talk to you about charlie.
# Decoded sentence: o
# -
# Input sentence: okay, last night after you guys broke up... so sorry to hear about that, by the way... well, charlie and i were talking, and..., well...
# Decoded sentence: o
# -
# Input sentence: wha...  what? what would give you that idea?
# Decoded sentence: o
# -
# Input sentence: yeah, we kissed, but... nothing else... nothing else happened, okay.
# Decoded sentence: o
# -
# Input sentence: what?
# Decoded sentence: o
# -
# Input sentence: are you serious?
# Decoded sentence: o
# -
# Input sentence: i am speachless... i mean the fact that you would put my happiness first like that. i mean, you're an incredible friend, you know that?
# Decoded sentence: o
# -
# Input sentence: no, i mean it. you are so loyal man, and selfless, and generous...
# Decoded sentence: o
# -
# Input sentence: you know what? i know chandler longer, so i always think of him as my best friend, but now... i may have to rethink some stuff...
# Decoded sentence: o
# -
# Input sentence: hey, if there is ever, anything i can do for you...
# Decoded sentence: o
# -
# Input sentence: thanks!
# Decoded sentence: o
# -
# Input sentence: excuse me!  you didn't tell him, did you?
# Decoded sentence: o
# -
# Input sentence: oh god! alright, fine. you know what joey, forget it. when we go back to new york, i will tell him.
# Decoded sentence: o
# -
# Input sentence: yeah, i tried to gnaw myself free.
# Decoded sentence: o
# -
# Input sentence: hi!
# Decoded sentence: o
# -
# Input sentence: well, i tried, but then he had a shampoo related emergency. so i guess now it's your turn again.
# Decoded sentence: o
# -
# Input sentence: yeah, 'cause that's what we do.
# Decoded sentence: o
# -
# Input sentence: okay, that sounds fair. it just means that once again we can't...
# Decoded sentence: o
# -
# Input sentence: no! of course we can wait. alright, so i guess that means good night then?
# Decoded sentence: o
# -
# Input sentence: goo--ood night!
# Decoded sentence: o
# -
# Input sentence: seriously, good night!
# Decoded sentence: o
# -
# Input sentence:
# Decoded sentence: o
# -
# Input sentence: we weren't doing anything!
# Decoded sentence: o
# -
# Input sentence: shhh.
# Decoded sentence: o
# -
# Input sentence: no, come on, that is a lie. we also kissed in barbados. yeah, you started it! i've got to chill.
# Decoded sentence: o
# -
# Input sentence: we feel so terrible about this, ross.
# Decoded sentence: o
# -
# Input sentence: so you two are..? and have you .. ed?
# Decoded sentence: o
# -
# Input sentence: but if i hadn't walked in here, would you..?
# Decoded sentence: o
# -
# Input sentence: hey, hey, hey... if you two are happy, then i'm happy for you.  i'm fine!
# Decoded sentence: o
# -
# Input sentence: absolutely.  i'm fine! totally fine. i don't know why it's coming out all loud and squeaky, 'cause really,  i'm fine. i'm not saying i wasn't a little surprised to see you guys kissing. i mean, at first i was like..  but now that i've had time to absorb it; lovin' this.
# Decoded sentence:
# -
# Input sentence: no. we should all have dinner. yes, we'll do it tomorrow night. i'll cook!!
# Decoded sentence: o
# -
# Input sentence: weird? what? what's weird? the only thing weird would be if someone didn't like mexican food, because i'm making fajitas!!
# Decoded sentence: o
# -
# Input sentence: hi frank. oh, my goodness, they've all gotten so big! which one is which again?
# Decoded sentence: o
# -
# Input sentence: well, what would we be doing?
# Decoded sentence: o
# -
# Input sentence: feel me up?
# Decoded sentence: o
# -
# Input sentence: oh, you bet.
# Decoded sentence: o
# -
# Input sentence: actually.. it's stuff you left at my apartment.
# Decoded sentence: o
# -
# Input sentence: and you know, you can just give me my stuff whenever you want.
# Decoded sentence: o
# -
# Input sentence: oh! that is so thoughtful.  she's a keeper. and what did you bring me?
# Decoded sentence: o
# -
# Input sentence: what? fine? because i am! aren't you? aren't you? aren't you? you see? who else is fine?
# Decoded sentence: o
# -
# Input sentence: oh, guys, this is fun, isn't it? you know? just the four of us. just hangin'.
# Decoded sentence: o
# -
# Input sentence: o is for "oh, wow!" the v is for this very surprising turn of events, which i'm still fine with by the way. e is for how extremely normal i find it. that you two are together. and now one day you might get married and have children of your own.
# Decoded sentence: o
# -
# Input sentence: hey, hey, it's fine. it's totally fine. we've got plenty of margaritas. it's all good. i don't even know what that's for.
# Decoded sentence: o
# -
# Input sentence: yeah, that's probably a good idea.
# Decoded sentence: o
# -
# Input sentence: uh-huh. okay. you know what, joey, i don't think he's ever gonna be okay with this.
# Decoded sentence: o
# -
# Input sentence: thanks. did you stay here all night?
# Decoded sentence: o
# -
# Input sentence: so you took off my pants and shoes?
# Decoded sentence: o
# -
# Input sentence: what do you mean?
# Decoded sentence: o
# -
# Input sentence: hey, what are you talking about? i'm fine!
# Decoded sentence: o
# -
# Input sentence: except we're not. i mean, we haven't been a couple in like, six years. oh my god, is that right? has it been that long?
# Decoded sentence: o
# -
# Input sentence: this is crazy. i mean, six years? and because of me you guys aren't gonna be together? can i ask you something? really, what is this thing with you and rachel?
# Decoded sentence: o
# -
# Input sentence: joey.
# Decoded sentence: o
# -
# Input sentence: and she feels the same way?
# Decoded sentence: o
# -
# Input sentence: well, then, maybe it's time we all moved on.
# Decoded sentence: o
# -
# Input sentence: no, but i wanna be. hey, i will be. besides, i'm with charlie, right? oh my god, i'm still with charlie, aren't i? i mean, she didn't see the dance, did she?
# Decoded sentence: o
# -
# Input sentence: yeah, i'm sure.
# Decoded sentence: o
# -
# Input sentence: so, you and rachel tonight, huh?
# Decoded sentence: o
# -
# Input sentence: wow! so tonight may be the night! you're nervous?
# Decoded sentence: o
# -
# Input sentence: what must it be like not to be crippled by fear and self-loathing.
# Decoded sentence: o
# -
# Input sentence: how can you be so confident?
# Decoded sentence: o
# -
# Input sentence: really? like you have a routine?
# Decoded sentence: o
# -
# Input sentence: really?
# Decoded sentence: o
# -
# Input sentence: you mean like this?
# Decoded sentence: o
# -
# Input sentence: oh, i see what you mean, that's quite nice.
# Decoded sentence: o
# -
# Input sentence: thanks for dinner.
# Decoded sentence: o
# -
# Input sentence: so.
# Decoded sentence: o
# -
# Input sentence: i say ‘cheesy line’, but ok.
# Decoded sentence: o
# -
# Input sentence: i am sorry, i don’t know, i am sorry, i don’t know why i did that! ok, so sorry. i am sorry! again... i don't know, i don’t know what happened, i must be nervous!
# Decoded sentence: o
# -
# Input sentence: ok, ok, ok. i promise, i promise, i promise, i won’t do it again. i really do. i promise. this is gonna be great.
# Decoded sentence: o
# -
# Input sentence: i did!
# Decoded sentence: o
# -
# Input sentence: absolutely! absolutely. i d... it’s just a little weird, it’s you, and it’s me, it's just gonna take some getting used to.
# Decoded sentence: o
# -
# Input sentence: ok, let’s work from the top down!  just work the bra, joe!
# Decoded sentence: o
# -
# Input sentence: okay.
# Decoded sentence: o
# -
# Input sentence: oh! ow!
# Decoded sentence: o
# -
# Input sentence: well this is romantic!
# Decoded sentence: o
